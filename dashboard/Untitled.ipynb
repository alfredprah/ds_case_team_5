# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../data/case2/dashboard_predictions.csv', index_col='id')

# %%
df=data[data['flag']==1]

# %%
df.loc[:,"reviewed_target"]=np.random.choice([0, 1, 2], df.shape[0])
# Out:
# C:\Users\rahmank\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df["reviewed_target"].fillna(0, inplace=True)
# Out:
# C:\Users\rahmank\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df
# Out:
#             keyword                 location  \
# id
# 192      aftershock                  Runcorn
# 292       ambulance         West Chester, PA
# 295       ambulance  Chorley, Lancashire, UK
# 351    annihilation                      NaN
# 359    annihilation                 Colorado
# ...             ...                      ...
# 10538     windstorm     28.709672,-97.376514
# 10577     windstorm                      NaN
# 10653        wounds               Vancouver
# 10703         wreck             Columbus, OH
# 10857           NaN                      NaN
#
#                                                     text  probability  target  \
# id
# 192                   Aftershock https://t.co/38Nhq9moEf     0.503656       0
# 292    Why should a helicopter ambulance ride to tran...     0.595757       0
# 295    so privileged and proud to wear this uniform.?...     0.527177       1
# 351    Allied Plans for the Annihilation of the Germa...     0.506448       1
# 359    U.S National Park Services Tonto National Fore...     0.512232       1
# ...                                                  ...          ...     ...
# 10538  San Patricio ÛÓ Windstorm insurance reform ke...     0.599170       1
# 10577  Texas Seeks Comment on Rules for Changes to Wi...     0.500569       1
# 10653  @WorldRunners @RunningRoom Day 3&amp;my wounds...     0.570175       0
# 10703  Interesting in watching a train wreck while ta...     0.583255       1
# 10857  To conference attendees! The blue line from th...     0.544078       0
#
#        flag  original_target  datetime_updated  reviewed_target
# id
# 192       1              NaN               NaN              0.0
# 292       1              NaN               NaN              0.0
# 295       1              NaN               NaN              0.0
# 351       1              NaN               NaN              0.0
# 359       1              NaN               NaN              0.0
# ...     ...              ...               ...              ...
# 10538     1              NaN               NaN              0.0
# 10577     1              NaN               NaN              0.0
# 10653     1              NaN               NaN              0.0
# 10703     1              NaN               NaN              0.0
# 10857     1              NaN               NaN              0.0
#
# [278 rows x 9 columns]
