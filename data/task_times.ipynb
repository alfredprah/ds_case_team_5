# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/timeseries_base.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        week  pid  episodeid contracttype admit_week_start  \
# 0          17  2018-12-31    6    17500.0          CT2       2018-12-31
# 1          18  2018-12-31    6    17793.0          CT2       2018-12-31
# 2          19  2018-12-31    6    18516.0          CT2       2018-12-31
# 3          20  2018-12-31    6    19016.0          CT2       2018-12-31
# 4          21  2018-12-31    6    19129.0          CT2       2018-12-31
#
#   discharge_week_start  len_of_stay   admitdate dischargedate  \
# 0           2019-01-14           17  2019-01-01    2019-01-18
# 1           2019-01-14           16  2019-01-01    2019-01-17
# 2           2019-01-28           30  2019-01-01    2019-01-31
# 3           2019-01-14           15  2019-01-01    2019-01-16
# 4           2019-01-07            7  2019-01-01    2019-01-08
#
#    admit_week_days  discharge_week_days  discharge_plus_admit  admit  \
# 0                6                    5                    11    1.0
# 1                6                    4                    10    1.0
# 2                6                    4                    10    1.0
# 3                6                    3                     9    1.0
# 4                6                    2                     8    1.0
#
#     regular  discharge
# 0  0.857143        0.0
# 1  0.857143        0.0
# 2  0.857143        0.0
# 3  0.857143        0.0
# 4  0.857143        0.0

# %%
len(df)
# Out:
# 148021

# %%
Task1 = 2.12
Task2 = 4.95
Task3 = 61.67
Task4 = 10.04
Task5 = 7.95
Task6 = 10.08
Task7 = 5
Task8 = 6.99
Task9 = 4.03
Task10 = 16.54
Task11 = 37.1
Task12 = 5.04
Task13 = 5
Task14 = 6.34
Task15 = 14.99
Task16 = 10
Task17 = 3

df['admit_time'] = 0
df['regular_time']=0
df['discharge_time']=0

# %%
df.loc[df['contracttype'] == 'CT1', 'regular_time'] = df['regular']*(Task9 + Task12 + Task15 + Task17 + Task14)
df.loc[df['contracttype'] == 'CT1', 'discharge_time'] = df['discharge']*(Task2 + Task8)
df.loc[df['contracttype'] == 'CT1', 'admit_time'] = df['admit']*(Task1 + Task4 + Task5 + Task6)

# %%
df.loc[df['contracttype'] == 'CT2', 'regular_time'] = df['regular']*(Task9 + Task11 + Task14 + Task17)
df.loc[df['contracttype'] == 'CT2', 'discharge_time'] = df['discharge']*(Task7 + Task8 + Task2 + Task10)
df.loc[df['contracttype'] == 'CT2', 'admit_time'] = df['admit']*(Task1 + Task3 + Task5 + Task6)

# %%
df.head(10)
# Out:
#    Unnamed: 0        week  pid  episodeid contracttype admit_week_start  \
# 0          17  2018-12-31    6    17500.0          CT2       2018-12-31
# 1          18  2018-12-31    6    17793.0          CT2       2018-12-31
# 2          19  2018-12-31    6    18516.0          CT2       2018-12-31
# 3          20  2018-12-31    6    19016.0          CT2       2018-12-31
# 4          21  2018-12-31    6    19129.0          CT2       2018-12-31
# 5          22  2018-12-31    6    19387.0          CT2       2018-12-31
# 6          66  2018-12-31    6    48172.0          CT2       2018-12-31
# 7          67  2018-12-31    6    48173.0          CT2       2018-12-31
# 8          68  2018-12-31    6    48174.0          CT2       2018-12-31
# 9          69  2018-12-31    6    48175.0          CT2       2018-12-31
#
#   discharge_week_start  len_of_stay   admitdate dischargedate  \
# 0           2019-01-14           17  2019-01-01    2019-01-18
# 1           2019-01-14           16  2019-01-01    2019-01-17
# 2           2019-01-28           30  2019-01-01    2019-01-31
# 3           2019-01-14           15  2019-01-01    2019-01-16
# 4           2019-01-07            7  2019-01-01    2019-01-08
# 5           2019-01-07           10  2019-01-01    2019-01-11
# 6           2019-01-07           11  2019-01-01    2019-01-12
# 7           2018-12-31            5  2019-01-01    2019-01-06
# 8           2019-01-21           24  2019-01-01    2019-01-25
# 9           2019-01-14           17  2019-01-01    2019-01-18
#
#    admit_week_days  discharge_week_days  discharge_plus_admit  admit  \
# 0                6                    5                    11    1.0
# 1                6                    4                    10    1.0
# 2                6                    4                    10    1.0
# 3                6                    3                     9    1.0
# 4                6                    2                     8    1.0
# 5                6                    5                    11    1.0
# 6                6                    6                    12    1.0
# 7                6                    7                    13    1.0
# 8                6                    5                    11    1.0
# 9                6                    5                    11    1.0
#
#     regular  discharge  admit_time  regular_time  discharge_time
# 0  0.857143        0.0       81.82         43.26            0.00
# 1  0.857143        0.0       81.82         43.26            0.00
# 2  0.857143        0.0       81.82         43.26            0.00
# 3  0.857143        0.0       81.82         43.26            0.00
# 4  0.857143        0.0       81.82         43.26            0.00
# 5  0.857143        0.0       81.82         43.26            0.00
# 6  0.857143        0.0       81.82         43.26            0.00
# 7  1.000000        1.0       81.82         50.47           33.48
# 8  0.857143        0.0       81.82         43.26            0.00
# 9  0.857143        0.0       81.82         43.26            0.00
